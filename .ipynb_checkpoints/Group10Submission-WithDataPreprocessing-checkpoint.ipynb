# %% [markdown]
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install nltk
# !pip install sklearn
# !pip install tensorflow
# !pip install clean-text
# !pip install googletrans

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from cleantext import clean
from googletrans import Translator
translator = Translator()

import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import WordNetLemmatizer



from sklearn import model_selection, metrics, preprocessing, ensemble
from sklearn.feature_extraction.text import CountVectorizer

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Conv1D, Bidirectional, LSTM, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

from fuzzywuzzy import fuzz

from tkinter import *
from tkinter import ttk
# Out:
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.
# [nltk_data] Downloading package punkt to C:\Users\SAMEER
# [nltk_data]     MISHRA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\SAMEER
# [nltk_data]     MISHRA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\SAMEER MISHRA\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Reading train dataset

file_path = "C:/Users/SAMEER MISHRA/Desktop/COLLEGE PRACTICAL PROGRAM FILES/6th SEM/Project/Code/Dataset/train.csv"
rdata = pd.read_csv(file_path, encoding = 'unicode_escape', engine ='python')
print("Total Data Row : ", rdata['id'].count())
rdata.head(10)
# Out:
# Total Data Row :  9752
#    id   keyword                     location  \
# 0   1    ablaze             Inang Pamantasan
# 1   2    ablaze  Twitter Lockout in progress
# 2   3    ablaze                  Concord, CA
# 3   4    ablaze                  Calgary, AB
# 4   5    ablaze                   Birmingham
# 5   6    ablaze                San Francisco
# 6   7  accident                       CLVLND
# 7   8  accident                Nashville, TN
# 8   9  accident              Santa Clara, CA
# 9  10  accident                           UK
#
#                                                                                                                                            text  \
# 0     Progressive greetings!\n\nIn about a month students would have set their pens ablaze in The Torch Publications'... http://t.co/9FxPiXQuJt
# 1                                            Rene Ablaze &amp; Jacinta - Secret 2k13 (Fallen Skies Edit) - Mar 30 2013  https://t.co/7MLMsUzV1Z
# 2    @Navista7 Steve these fires out here are something else! California is a tinderbox - and this clown was setting my 'hood ablaze @News24680
# 3                                                              #NowPlaying: Rene Ablaze &amp; Ian Buff - Magnitude http://t.co/Av2JSjfFtc  #EDM
# 4                                                                  @nxwestmidlands huge fire at Wholesale markets ablaze http://t.co/rwzbFVNXER
# 5                                                         @ablaze what time does your talk go until? I don't know if I can make it due to work.
# 6  'I can't have kids cuz I got in a bicycle accident &amp; split my testicles. it's impossible for me to have kids' MICHAEL YOU ARE THE FATHER
# 7                                            Accident on I-24 W #NashvilleTraffic. Traffic moving 8m slower than usual. https://t.co/0GHk693EgJ
# 8                   Accident center lane blocked in #SantaClara on US-101 NB before Great America Pkwy #BayArea #Traffic http://t.co/pmlOhZuRWR
# 9             http://t.co/GKYe6gjTk5 Had a #personalinjury accident this summer? Read our advice &amp; see how a #solicitor can help #OtleyHour
#
#    target
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
# 5       0
# 6       0
# 7       1
# 8       1
# 9       0

# %%
# Plotting target value counts


print("Count of 0 in target:",(rdata['target']==0).sum())
print("Count of 1 in target:",(rdata['target']==1).sum())

plt.figure(figsize=(20,10))
rdata['target'].value_counts().plot(kind="barh",color="green")
plt.suptitle("Dataset", fontsize=30)
plt.show()
# Out:
# Count of 0 in target: 4349
# Count of 1 in target: 5403

# %%
#Printing NaN counts

print("NaN in id       : ", rdata['id'].isna().sum())
print("NaN in keyword  : ", rdata['keyword'].isna().sum())
print("NaN in location : ", rdata['location'].isna().sum())
print("NaN in text     : ", rdata['text'].isna().sum())
print("NaN in target   : ", rdata['target'].isna().sum())
# Out:
# NaN in id       :  0
# NaN in keyword  :  2188
# NaN in location :  4660
# NaN in text     :  0
# NaN in target   :  0

# %%
#Creating new attribute 'word_count'

rdata['word_count'] = rdata['text'].apply(lambda x: len(x.split(" ")) )

# %%
# printing rows containing less than 3 words

for i in range(rdata['word_count'].count()):
  if rdata['word_count'][i]<3:
    print(rdata['text'][i])
# Out:
# Love skiing
# LOOOOOOL
# Cooool :)
# The end!
# Aftershock https://t.co/xMWODFMtUI
# Aftershock https://t.co/jV8ppKhJY7
# Apocalypse please
# Armageddon https://t.co/uCSUDk3q1d
# @paddytomlinson1 ARMAGEDDON
# @local_arsonist LMFAO
# @kynespeace *blight
# Stats http://t.co/U7vavyrGv9
# @Blizzard_Gamin ight
# Crushed
# eggs desolate
# Electrocute yourself
# Emergency surgery
# fatal attraction
# Fatality!
# fatality
# @Babybackreeve FATALITY!!!!!!!!!!
# Fatality https://t.co/GF5qjGoyCi
# Fatality ????
# Flattened https://t.co/9jCIBenckz
# hurricane?? sick!
# Bad day
# Meltdown
# Err:509
# Obliterated
# @BizzleMahomie SCREAMING
# @Scalpium SCREAMING
# #NoChillLukeHammings
# IM SCREAMING
# *screams internally*
# *screams* http://t.co/PU7C4Hhbxj
# @RealJaxClone *screams*
# this storm????
# :: Survive??
# Truth...
# https://t.co/h6amECX5K7
# #News
# #BBC
# #CNN
# #Islam
# #Truth
# #god
# #ISIS
# #terrorism
# #Quran
# #Lies http://t.co/B8iWRdxcm0
# Truth...
# https://t.co/nXS3Z1kxiD
# #News
# #BBC
# #CNN
# #Islam
# #Truth
# #god
# #ISIS
# #terrorism
# #Quran
# #Lies http://t.co/UDKMAdKuzY
# Truth...
# https://t.co/beJfTYgJIL
# #News
# #BBC
# #CNN
# #Islam
# #Truth
# #god
# #ISIS
# #terrorism
# #Quran
# #Lies http://t.co/jlCZiDZ7Vu
# Truth...
# https://t.co/2Y4RGob7pj
# #News
# #BBC
# #CNN
# #Islam
# #Truth
# #god
# #ISIS
# #terrorism
# #Quran
# #Lies http://t.co/mVes6VsSyN
# Truth...
# https://t.co/p5ZIcjUdXO
# #News
# #BBC
# #CNN
# #Islam
# #Truth
# #god
# #ISIS
# #terrorism
# #Quran
# #Lies http://t.co/kZhB8zX6YC
# Truth...
# https://t.co/k44tL3rfMy
# #News
# #BBC
# #CNN
# #Islam
# #Truth
# #god
# #ISIS
# #terrorism
# #Quran
# #Lies http://t.co/ipT0hoNoTI
# Truth...
# https://t.co/4ZQrsAQrRT
# #News
# #BBC
# #CNN
# #Islam
# #Truth
# #god
# #ISIS
# #terrorism
# #Quran
# #Lies http://t.co/6ar3UKvsxw
# Thunder???
# Weapon's catalogue~
# Wrecked emotions.
# Sirens everywhere!
# Omg earthquake

# %%
#Removing the text with less than 3 words

rdata = rdata[rdata['word_count']>2]
rdata = rdata.reset_index()

# %%
#Checking whether data is removed or not

flag=0
for i in range(rdata['word_count'].count()):
  if rdata['word_count'][i]<3:
    print(rdata['text'][i])
    flag=1
if flag==0:
  print("0 texts with word (count < 3)")
# Out:
# 0 texts with word (count < 3)

# %%
# Clean text columns

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(each_text):    
    #removing emoji
    each_text_no_emoji = clean(each_text, no_emoji=True)
    
    #removing URL from text
    each_text_no_url = re.sub(r"http\S+", "", each_text_no_emoji)
        
    # removing numbers from text
    text_no_num = re.sub(r'\d+', '', each_text_no_url)

    # tokenizing each text
    word_tokens = word_tokenize(text_no_num)
    
    # removing special character
    clean_text = []
    for word in word_tokens:
        clean_text.append("".join([z for z in word if z.isalnum()]))

    # removing stop words and lower
    text_with_no_stop_word = [w.lower() for w in clean_text if not w in stop_words]  

    # do lemmatization
    stemmed_text = [lemmatizer.lemmatize(w) for w in text_with_no_stop_word]
    
    return " ".join(" ".join(stemmed_text).split())


rdata['clean_text'] = rdata['text'].apply(lambda x: clean_text(x) )
rdata['keyword'] = rdata['keyword'].fillna("none")
rdata['clean_keyword'] = rdata['keyword'].apply(lambda x: clean_text(x) )

# %%
# Combine column 'clean_keyword' and 'clean_text' into one

rdata['keyword_text'] = rdata['clean_keyword'] + " " + rdata["clean_text"]

# %%
#The Dataset after all actions

rdata.head(10)
# Out:
#    index  id   keyword                     location  \
# 0      0   1    ablaze             Inang Pamantasan
# 1      1   2    ablaze  Twitter Lockout in progress
# 2      2   3    ablaze                  Concord, CA
# 3      3   4    ablaze                  Calgary, AB
# 4      4   5    ablaze                   Birmingham
# 5      5   6    ablaze                San Francisco
# 6      6   7  accident                       CLVLND
# 7      7   8  accident                Nashville, TN
# 8      8   9  accident              Santa Clara, CA
# 9      9  10  accident                           UK
#
#                                                                                                                                            text  \
# 0     Progressive greetings!\n\nIn about a month students would have set their pens ablaze in The Torch Publications'... http://t.co/9FxPiXQuJt
# 1                                            Rene Ablaze &amp; Jacinta - Secret 2k13 (Fallen Skies Edit) - Mar 30 2013  https://t.co/7MLMsUzV1Z
# 2    @Navista7 Steve these fires out here are something else! California is a tinderbox - and this clown was setting my 'hood ablaze @News24680
# 3                                                              #NowPlaying: Rene Ablaze &amp; Ian Buff - Magnitude http://t.co/Av2JSjfFtc  #EDM
# 4                                                                  @nxwestmidlands huge fire at Wholesale markets ablaze http://t.co/rwzbFVNXER
# 5                                                         @ablaze what time does your talk go until? I don't know if I can make it due to work.
# 6  'I can't have kids cuz I got in a bicycle accident &amp; split my testicles. it's impossible for me to have kids' MICHAEL YOU ARE THE FATHER
# 7                                            Accident on I-24 W #NashvilleTraffic. Traffic moving 8m slower than usual. https://t.co/0GHk693EgJ
# 8                   Accident center lane blocked in #SantaClara on US-101 NB before Great America Pkwy #BayArea #Traffic http://t.co/pmlOhZuRWR
# 9             http://t.co/GKYe6gjTk5 Had a #personalinjury accident this summer? Read our advice &amp; see how a #solicitor can help #OtleyHour
#
#    target  word_count  \
# 0       0          17
# 1       0          16
# 2       1          23
# 3       0          11
# 4       1           8
# 5       0          19
# 6       0          27
# 7       1          12
# 8       1          16
# 9       0          18
#
#                                                                               clean_text  \
# 0              progressive greeting month student would set pen ablaze torch publication
# 1                                       rene ablaze jacinta secret k fallen sky edit mar
# 2  navista steve fire something else california tinderbox clown setting hood ablaze news
# 3                                          nowplaying rene ablaze ian buff magnitude edm
# 4                                       nxwestmidlands huge fire wholesale market ablaze
# 5                                              ablaze time talk go nt know make due work
# 6        ca nt kid cuz got bicycle accident split testicle impossible kid michael father
# 7                                accident w nashvilletraffic traffic moving slower usual
# 8        accident center lane blocked santaclara u nb great america pkwy bayarea traffic
# 9                personalinjury accident summer read advice see solicitor help otleyhour
#
#   clean_keyword  \
# 0        ablaze
# 1        ablaze
# 2        ablaze
# 3        ablaze
# 4        ablaze
# 5        ablaze
# 6      accident
# 7      accident
# 8      accident
# 9      accident
#
#                                                                                    keyword_text
# 0              ablaze progressive greeting month student would set pen ablaze torch publication
# 1                                       ablaze rene ablaze jacinta secret k fallen sky edit mar
# 2  ablaze navista steve fire something else california tinderbox clown setting hood ablaze news
# 3                                          ablaze nowplaying rene ablaze ian buff magnitude edm
# 4                                       ablaze nxwestmidlands huge fire wholesale market ablaze
# 5                                              ablaze ablaze time talk go nt know make due work
# 6      accident ca nt kid cuz got bicycle accident split testicle impossible kid michael father
# 7                              accident accident w nashvilletraffic traffic moving slower usual
# 8      accident accident center lane blocked santaclara u nb great america pkwy bayarea traffic
# 9              accident personalinjury accident summer read advice see solicitor help otleyhour

# %% [markdown]
# # LSTM Model:

# %%
feature = 'keyword_text'
label = "target"

# split train and test
X_train, X_test,y_train, y_test = model_selection.train_test_split(rdata[feature],
                                                                   rdata[label],
                                                                   test_size=0.2,
                                                                   random_state=0, 
                                                                   shuffle=True)

# %%
# Define some hyperparameters

path_to_glove_file = 'C:/Users/SAMEER MISHRA/Desktop/COLLEGE PRACTICAL PROGRAM FILES/6th SEM/Project/Code/glove.6B/glove.6B.300d.txt'
embedding_dim = 300
learning_rate = 1e-3
batch_size = 1024
epochs = 20
sequence_len = 100

# %%
# Define train and test labels

y_train_LSTM = y_train.values.reshape(-1,1)
y_test_LSTM = y_test.values.reshape(-1,1)

print("Training Y shape:", y_train_LSTM.shape)
print("Testing Y shape:", y_test_LSTM.shape)
# Out:
# Training Y shape: (7762, 1)
# Testing Y shape: (1941, 1)

# %%
# Tokenize train data

tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

word_index = tokenizer.word_index
vocab_size = len(word_index) + 1
print("Vocabulary Size: ", vocab_size)
# Out:
# Vocabulary Size:  13299

# %%
# Pad train and test 

X_train = pad_sequences(tokenizer.texts_to_sequences(X_train), maxlen=sequence_len)
X_test = pad_sequences(tokenizer.texts_to_sequences(X_test), maxlen=sequence_len)

print("Training X shape: ", X_train.shape)
print("Testing X shape: ", X_test.shape)
# Out:
# Training X shape:  (7762, 100)
# Testing X shape:  (1941, 100)

# %%
# Read word embeddings

embeddings_index = {}
with open(path_to_glove_file, encoding="utf8") as f:
    for line in f:
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ")
        embeddings_index[word] = coefs

print("Found %s word vectors." % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
# Define embedding layer in Keras

embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
        
embedding_layer = tf.keras.layers.Embedding(vocab_size,
                                            embedding_dim,
                                            weights=[embedding_matrix],
                                            input_length=sequence_len,
                                            trainable=False)

# %%
# Define model architecture

sequence_input = Input(shape=(sequence_len, ), dtype='int32')
embedding_sequences = embedding_layer(sequence_input)

x = Conv1D(128, 5, activation='relu')(embedding_sequences)
x = Bidirectional(LSTM(128, dropout=0.5, recurrent_dropout=0.2))(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)
model = Model(sequence_input, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 100, 300)          3989700
# _________________________________________________________________
# conv1d (Conv1D)              (None, 96, 128)           192128
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               263168
# _________________________________________________________________
# dense (Dense)                (None, 512)               131584
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 4,839,749
# Trainable params: 850,049
# Non-trainable params: 3,989,700
# _________________________________________________________________

# %%
# Optimize the model
model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the LSTM Model

history = model.fit(X_train,
                    y_train,
                    batch_size=batch_size,
                    epochs=epochs, 
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 8/8 [==============================] - 53s 6s/step - loss: 0.5980 - accuracy: 0.6379 - val_loss: 0.4319 - val_accuracy: 0.8109
# Epoch 2/20
# 8/8 [==============================] - 38s 5s/step - loss: 0.4200 - accuracy: 0.8174 - val_loss: 0.3769 - val_accuracy: 0.8377
# Epoch 3/20
# 8/8 [==============================] - 41s 5s/step - loss: 0.3679 - accuracy: 0.8397 - val_loss: 0.3605 - val_accuracy: 0.8434
# Epoch 4/20
# 8/8 [==============================] - 43s 5s/step - loss: 0.3370 - accuracy: 0.8542 - val_loss: 0.3442 - val_accuracy: 0.8521
# Epoch 5/20
# 8/8 [==============================] - 50s 6s/step - loss: 0.3095 - accuracy: 0.8674 - val_loss: 0.3431 - val_accuracy: 0.8573
# Epoch 6/20
# 8/8 [==============================] - 52s 7s/step - loss: 0.2905 - accuracy: 0.8761 - val_loss: 0.3347 - val_accuracy: 0.8604
# Epoch 7/20
# 8/8 [==============================] - 55s 7s/step - loss: 0.2638 - accuracy: 0.8907 - val_loss: 0.3574 - val_accuracy: 0.8537
# Epoch 8/20
# 8/8 [==============================] - 56s 7s/step - loss: 0.2394 - accuracy: 0.9031 - val_loss: 0.3838 - val_accuracy: 0.8444
# Epoch 9/20
# 8/8 [==============================] - 61s 8s/step - loss: 0.2155 - accuracy: 0.9161 - val_loss: 0.4022 - val_accuracy: 0.8496
# Epoch 10/20
# 8/8 [==============================] - 64s 8s/step - loss: 0.1898 - accuracy: 0.9271 - val_loss: 0.4097 - val_accuracy: 0.8506
# Epoch 11/20
# 8/8 [==============================] - 69s 9s/step - loss: 0.1620 - accuracy: 0.9389 - val_loss: 0.5170 - val_accuracy: 0.8413
# Epoch 12/20
# 8/8 [==============================] - 68s 8s/step - loss: 0.1406 - accuracy: 0.9486 - val_loss: 0.4848 - val_accuracy: 0.8418
# Epoch 13/20
# 8/8 [==============================] - 75s 9s/step - loss: 0.1254 - accuracy: 0.9519 - val_loss: 0.5309 - val_accuracy: 0.8387
# Epoch 14/20
# 8/8 [==============================] - 73s 9s/step - loss: 0.1081 - accuracy: 0.9597 - val_loss: 0.5235 - val_accuracy: 0.8423
# Epoch 15/20
# 8/8 [==============================] - 74s 9s/step - loss: 0.0944 - accuracy: 0.9664 - val_loss: 0.5725 - val_accuracy: 0.8351
# Epoch 16/20
# 8/8 [==============================] - 74s 9s/step - loss: 0.0851 - accuracy: 0.9691 - val_loss: 0.6004 - val_accuracy: 0.8418
# Epoch 17/20
# 8/8 [==============================] - 77s 10s/step - loss: 0.0860 - accuracy: 0.9668 - val_loss: 0.5611 - val_accuracy: 0.8501
# Epoch 18/20
# 8/8 [==============================] - 96s 12s/step - loss: 0.0840 - accuracy: 0.9686 - val_loss: 0.5865 - val_accuracy: 0.8501
# Epoch 19/20
# 8/8 [==============================] - 214s 27s/step - loss: 0.0709 - accuracy: 0.9733 - val_loss: 0.6482 - val_accuracy: 0.8367
# Epoch 20/20
# 8/8 [==============================] - 217s 27s/step - loss: 0.0597 - accuracy: 0.9782 - val_loss: 0.6687 - val_accuracy: 0.8475

# %%
# Plot train accuracy and loss
accuraties = history.history['accuracy']
losses = history.history['loss']
accuraties_losses = list(zip(accuraties,losses))

accuraties_losses_df = pd.DataFrame(accuraties_losses, columns={"accuraties", "losses"})

plt.figure(figsize=(10,4))
plt.suptitle("Train Accuracy vs Train Loss")
sns.lineplot(data=accuraties_losses_df)
plt.show()

# %%
# Evaluate the model

predicted = model.predict(X_test, verbose=1, batch_size=10000)
y_predicted = [1 if each > 0.5 else 0 for each in predicted]
score, test_accuracy = model.evaluate(X_test, y_test, batch_size=10000)

print("Test Accuracy: ", test_accuracy)
print(metrics.classification_report(list(y_test), y_predicted))
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step - loss: 0.6687 - accuracy: 0.8475
# Test Accuracy:  0.847501277923584
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       843
#            1       0.88      0.84      0.86      1098
#
#     accuracy                           0.85      1941
#    macro avg       0.84      0.85      0.85      1941
# weighted avg       0.85      0.85      0.85      1941

# %%
# Plot confusion matrix

conf_matrix = metrics.confusion_matrix(y_test, y_predicted)

fig, ax = plt.subplots()
sns.heatmap(conf_matrix, cbar=False, cmap='Reds', annot=True, fmt='d')
ax.set(xlabel="Predicted Value", ylabel="True Value", title="Confusion Matrix")
ax.set_yticklabels(labels=['0', '1'], rotation=0)
plt.show()

# %%
root=Tk()
root.geometry("1000x720")
root['bg']='aqua'

bg = PhotoImage(file = "C:/Users/SAMEER MISHRA/Desktop/COLLEGE PRACTICAL PROGRAM FILES/6th SEM/Project/Code/Extra/Logo/logo.png"
               ,master=root)
# # Show image using label
label1 = Label( root, image = bg ,bg='aqua') 
label1.place(x = 440, y = 15)
root.title("DIVVA")
t1=Label(root,text="ENTER TEXT HERE :",font=("Times New Roman Bold", 18),fg='blue',bg='aqua')
t1.place(x=63,y=215)
global e1  
e1=Text(root,width="75",wrap=WORD)
e1.place(x=320,y=160,height="150")
e1.config(bg='#eafaac',fg='blue')
#use get() method to get text from field and use it in verify and validate tweet functions

def verify():
    translated_text = translator.translate(e1.get("1.0","end-1c"),dest="en")   
    x = translated_text.text
    data = {"id":16747883,
        "text":x}

    userData = pd.DataFrame(data, index=[0])
    userData['clean_text'] = userData['text'].apply(lambda x: clean_text(x) )
    x = userData['clean_text'][0]
    
    data = pad_sequences(tokenizer.texts_to_sequences(userData['clean_text']), maxlen=sequence_len)
    predicted = model.predict(data, verbose=1, batch_size=10000)
    y_predicted = [1 if each > 0.5 else 0 for each in predicted]
    validateVerify(x,y_predicted[0])

def validateVerify(x,key):
    if key==1:
        tval.config(bg='#3c992e')
        tval.config(text='DISASTER DETECTED')
        temp = 0
        df1 = pd.read_csv("Dataset/tweets.csv")
        df1 = df1.dropna()
        for t in df1.Tweet:
            temp = max(temp,fuzz.ratio(x,t))
        progressbar['value']=temp
        tver.config(text=str(temp)+'%')
    else:
        tval.config(bg='red')
        tval.config(text='NO DISASTER')
        progressbar['value']=0
        temp = 0
        tver.config(text=str(temp)+'%')
        

Button(root,text="VERIFY AND VALIDATE",font=("Times New Roman Bold", 15),command=verify,height="2",width="28",bg='blue',fg='white').place(x=335,y=400)
t2=Label(root,text="VERIFICATION : ",font=("Times New Roman Bold", 12),bg='aqua',fg='blue')
t2.place(x=280,y=540)
global tval
tval=Label(root,text="",height="3",width="28")
tval.place(x=430,y=530)
tval.config(fg='white')


trough = 'white'
bar = '#000000'
style1=ttk.Style()
style1.configure("bar.Horizontal.TProgressbar", troughcolor=trough, 
                bordercolor=trough, background=bar, lightcolor=bar, 
                darkcolor=bar)
global progressbar
progressbar = ttk.Progressbar(root,style="bar.Horizontal.TProgressbar", orient = HORIZONTAL,
              length = 100, mode = 'determinate')
progressbar.place(x=430,y=610,width="200",height="25")

global tver
tver=Label(root,text="",height="3",width="5",font=("Times New Roman Bold", 15))
tver.place(x=630,y=585)
tver.config(fg='blue')
tver.config(bg='aqua')

t3=Label(root,text="VALIDATION (%) :",font=("Times New Roman Bold", 12),bg='aqua',fg='blue')
t3.place(x=280,y=610)

root.mainloop()
